# %% [markdown]
# <a href="https://colab.research.google.com/github/ycw0363/statseminar/blob/main/hw3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.0     ✔ dplyr   1.0.5
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
install.packages("nycflights13")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(nycflights13)

# %%
flights %>% filter(month == 10 & day == 10) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 10    10  457      500            -3        637      648
# 2 2013 10    10  515      517            -2        736      757
# 3 2013 10    10  537      545            -8        923      933
# 4 2013 10    10  540      545            -5        845      855
# 5 2013 10    10  542      550            -8        941      932
# 6 2013 10    10  544      545            -1        811      827
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 -11       US      1843   N564UW  EWR    CLT   83       529     5     0
# 2 -21       UA       252   N544UA  EWR    IAH  178      1400     5    17
# 3 -10       B6      1403   N608JB  JFK    SJU  203      1598     5    45
# 4 -10       AA      2243   N5EMAA  JFK    MIA  153      1089     5    45
# 5   9       B6       939   N517JB  JFK    BQN  204      1576     5    50
# ...

# %%
flights %>% filter(month ==10, day == 10) %>% filter(dest == 'IAH') %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 10    10  515      517            -2         736      757
# 2 2013 10    10  544      545            -1         811      827
# 3 2013 10    10  631      630             1         902      919
# 4 2013 10    10  720      725            -5         944     1008
# 5 2013 10    10  738      720            18        1001     1000
# 6 2013 10    10  850      855            -5        1139     1156
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 -21       UA       252   N544UA  EWR    IAH  178      1400     5    17
# 2 -16       UA      1714   N29717  LGA    IAH  186      1416     5    45
# 3 -17       UA      1454   N21723  LGA    IAH  186      1416     6    30
# 4 -24       UA       212   N677UA  EWR    IAH  178      1400     7    25
# 5   1       UA       261   N566UA  LGA    IAH  183      1416     7    20
# ...

# %%
arrange(flights, month, day, dep_time) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
select(flights, year:day) %>% head()
# Out:
#   year month day
# 1 2013 1     1
# 2 2013 1     1
# 3 2013 1     1
# 4 2013 1     1
# 5 2013 1     1
# 6 2013 1     1

# %%
ggplot(data = mpg,mapping = aes(x = displ, y = hwy)) + 
  geom_point() + geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg,mapping = aes(x = displ, y = hwy)) + 
  geom_point() + geom_smooth() +
  theme(axis.line= element_line(size=.8, colour = "black"),
        panel.grid.minor = element_blank(),
        text = element_text(size = 25))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
